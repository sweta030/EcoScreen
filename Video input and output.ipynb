# %%
# TEST WITH IMAGE

# %%
import cv2
import numpy as np
from ultralytics import YOLO
from scipy.spatial import distance

def draw_road_polygon_on_image(img_path, output_path):
    display_size = (800, 600)
    
    # Read the image
    image = cv2.imread(img_path)
    
    # Load the models
    model_human = YOLO("best (HUM).pt")
    model_screen = YOLO("best_SCR.pt")
    
    # Perform prediction using the models
    r = model_human.predict(img_path)
    l = model_screen.predict(img_path)
    
    # Initialize lists for polygons
    screen_polygons = []
    human_polygons = []

    # Draw polygons for model_screen
    for mask_points in l[0].masks.xy:
        polygon_points = np.array(mask_points, np.int32)
        polygon_points = polygon_points.reshape((-1, 1, 2))
        screen_polygons.append(polygon_points)
    
    # Draw polygons for model_human
    for mask_points in r[0].masks.xy:
        polygon_points = np.array(mask_points, np.int32)
        polygon_points = polygon_points.reshape((-1, 1, 2))
        human_polygons.append(polygon_points)
    
    # Process human polygons and screen polygons
    for human_polygon in human_polygons:
        min_dist = float('inf')
        closest_human_point = None
        closest_screen_point = None
        closest_screen_polygon = None
        
        # Find the nearest screen polygon
        for screen_polygon in screen_polygons:
            for human_point in human_polygon:
                for screen_point in screen_polygon:
                    dist = distance.euclidean(human_point[0], screen_point[0])
                    if dist < min_dist:
                        min_dist = dist
                        closest_human_point = human_point[0]
                        closest_screen_point = screen_point[0]
                        closest_screen_polygon = screen_polygon
        
        # Draw the line and masks if a valid closest point is found
        if closest_human_point is not None and closest_screen_point is not None:
            cv2.line(image, tuple(closest_human_point), tuple(closest_screen_point), color=(255, 0, 0), thickness=5)
            
            # Display the Euclidean distance
            midpoint = ((closest_human_point[0] + closest_screen_point[0]) // 2,
                        (closest_human_point[1] + closest_screen_point[1]) // 2)
            cv2.putText(image, f"{min_dist:.2f}", midpoint, cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 2)
            
            # Draw the human mask based on the distance
            human_mask_color = (0, 255, 0) if min_dist <= 400 else (0, 0, 255)
            cv2.fillPoly(image, [human_polygon], color=human_mask_color)
        
        # Mark screen polygons
        if closest_screen_polygon is not None:
            # Mark the screen polygon blue if within range, pink otherwise
            screen_color = (255, 0, 0) if min_dist <= 400 else (255, 105, 180)  # Pink color
            cv2.fillPoly(image, [closest_screen_polygon], color=screen_color)

    # Resize the image for display
    resized_image = cv2.resize(image, display_size, interpolation=cv2.INTER_AREA)
    
    # Save the image
    cv2.imwrite(output_path, resized_image)

# Example usage
draw_road_polygon_on_image('3.jpg', '3_OUTPUT.jpg')
# Out:
# image 1/1 C:\Users\ASUS\Desktop\GAMA\3.jpg: 480x640 1 person, 1015.2ms
# Speed: 2.0ms preprocess, 1015.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 C:\Users\ASUS\Desktop\GAMA\3.jpg: 480x640 1 onscreen, 1004.7ms
# Speed: 3.0ms preprocess, 1004.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)

# %%
# TEST WITH VIDEO

# %%
import cv2
import numpy as np
from ultralytics import YOLO
from scipy.spatial import distance

def process_frame(frame, model_human, model_screen):
    display_size = (800, 600)
    
    # Perform prediction using the models
    r = model_human.predict(frame)
    l = model_screen.predict(frame)
    
    # Draw polygons for model_screen (on screen and off screen)
    screen_polygons = []
    off_screen_polygons = []
    if l and l[0].masks:  # Ensure there are valid masks
        for mask_points in l[0].masks.xy:
            polygon_points = np.array(mask_points, np.int32)
            polygon_points = polygon_points.reshape((-1, 1, 2))
            if 'on' in l[0].names:
                screen_polygons.append(polygon_points)
            else:
                off_screen_polygons.append(polygon_points)
    
    # Draw blue mask for off screen
    for off_screen_polygon in off_screen_polygons:
        cv2.fillPoly(frame, [off_screen_polygon], color=(255, 0, 0))
    
    # Draw polygons for model_human
    human_polygons = []
    if r and r[0].masks:  # Ensure there are valid masks
        for mask_points in r[0].masks.xy:
            polygon_points = np.array(mask_points, np.int32)
            polygon_points = polygon_points.reshape((-1, 1, 2))
            human_polygons.append(polygon_points)
    
    # Process human polygons and screen polygons
    for human_polygon in human_polygons:
        min_dist = float('inf')
        closest_human_point = None
        closest_screen_point = None
        closest_screen_polygon = None
        
        # Find the nearest screen polygon
        for screen_polygon in screen_polygons:
            for human_point in human_polygon:
                for screen_point in screen_polygon:
                    dist = distance.euclidean(human_point[0], screen_point[0])
                    if dist < min_dist:
                        min_dist = dist
                        closest_human_point = human_point[0]
                        closest_screen_point = screen_point[0]
                        closest_screen_polygon = screen_polygon
        
        # Draw the line and masks if a valid closest point is found
        if closest_human_point is not None and closest_screen_point is not None:
            cv2.line(frame, tuple(closest_human_point), tuple(closest_screen_point), color=(255, 0, 0), thickness=5)
            
            # Display the Euclidean distance
            midpoint = ((closest_human_point[0] + closest_screen_point[0]) // 2,
                        (closest_human_point[1] + closest_screen_point[1]) // 2)
            cv2.putText(frame, f"{min_dist:.2f}", midpoint, cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 2)
            
            # Draw the human mask based on the distance
            human_mask_color = (0, 0, 255) if min_dist < 400 else (0, 255, 255)
            cv2.fillPoly(frame, [human_polygon], color=human_mask_color)
        
        # Mark screen polygons
        if closest_screen_polygon is not None:
            # Mark the screen polygon green if within range, violet otherwise
            screen_color = (0, 255, 0) if min_dist < 400 else (238, 130, 238)
            cv2.fillPoly(frame, [closest_screen_polygon], color=screen_color)
    
    # Resize the image for display
    resized_frame = cv2.resize(frame, display_size, interpolation=cv2.INTER_AREA)
    
    return resized_frame

def process_video(input_path, output_path):
    # Open video capture
    cap = cv2.VideoCapture(input_path)
    
    # Get the codec information and create a VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'XVID')  # Codec for .avi files
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
    
    # Load the models
    model_human = YOLO("best (HUM).pt")
    model_screen = YOLO("best_SCR.pt")
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        # Process the frame
        processed_frame = process_frame(frame, model_human, model_screen)
        
        # Write the frame to the output video
        out.write(processed_frame)
    
    # Release resources
    cap.release()
    out.release()
    cv2.destroyAllWindows()

# Example usage
process_video('testfile.mp4', 'output_video.mp4')
# Out:
# 0: 384x640 (no detections), 892.4ms
# Speed: 3.5ms preprocess, 892.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 898.9ms
# Speed: 3.0ms preprocess, 898.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 958.2ms
# Speed: 2.0ms preprocess, 958.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 929.9ms
# Speed: 2.0ms preprocess, 929.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 894.3ms
# Speed: 2.0ms preprocess, 894.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 871.5ms
# Speed: 2.0ms preprocess, 871.5ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 872.6ms
# Speed: 2.1ms preprocess, 872.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 869.8ms
# Speed: 1.9ms preprocess, 869.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 868.4ms
# Speed: 1.9ms preprocess, 868.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 883.2ms
# Speed: 1.9ms preprocess, 883.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 887.7ms
# Speed: 2.0ms preprocess, 887.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 866.6ms
# Speed: 2.0ms preprocess, 866.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 878.6ms
# Speed: 1.9ms preprocess, 878.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 864.0ms
# Speed: 2.1ms preprocess, 864.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 867.3ms
# Speed: 1.9ms preprocess, 867.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 878.7ms
# Speed: 3.0ms preprocess, 878.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 882.2ms
# Speed: 2.0ms preprocess, 882.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 868.4ms
# Speed: 2.0ms preprocess, 868.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 878.0ms
# Speed: 1.9ms preprocess, 878.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 882.4ms
# Speed: 2.0ms preprocess, 882.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 868.9ms
# Speed: 1.9ms preprocess, 868.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 879.0ms
# Speed: 2.1ms preprocess, 879.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 884.8ms
# Speed: 3.2ms preprocess, 884.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 866.9ms
# Speed: 1.6ms preprocess, 866.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 883.9ms
# Speed: 2.6ms preprocess, 883.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 868.5ms
# Speed: 2.0ms preprocess, 868.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 862.4ms
# Speed: 2.0ms preprocess, 862.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 876.8ms
# Speed: 2.0ms preprocess, 876.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 871.8ms
# Speed: 2.0ms preprocess, 871.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 897.8ms
# Speed: 2.5ms preprocess, 897.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 862.7ms
# Speed: 2.0ms preprocess, 862.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 891.6ms
# Speed: 2.0ms preprocess, 891.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 880.1ms
# Speed: 3.0ms preprocess, 880.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 864.7ms
# Speed: 1.9ms preprocess, 864.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 859.6ms
# Speed: 2.5ms preprocess, 859.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 874.2ms
# Speed: 2.0ms preprocess, 874.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 877.3ms
# Speed: 2.0ms preprocess, 877.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 873.0ms
# Speed: 2.5ms preprocess, 873.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 861.5ms
# Speed: 3.0ms preprocess, 861.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 830.9ms
# Speed: 2.1ms preprocess, 830.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 869.6ms
# Speed: 2.0ms preprocess, 869.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 872.9ms
# Speed: 2.9ms preprocess, 872.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 873.7ms
# Speed: 3.5ms preprocess, 873.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 872.8ms
# Speed: 2.5ms preprocess, 872.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 872.2ms
# Speed: 2.0ms preprocess, 872.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 884.6ms
# Speed: 2.0ms preprocess, 884.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 874.2ms
# Speed: 2.0ms preprocess, 874.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 876.3ms
# Speed: 2.0ms preprocess, 876.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 882.5ms
# Speed: 2.0ms preprocess, 882.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 886.9ms
# Speed: 2.7ms preprocess, 886.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 879.8ms
# Speed: 2.0ms preprocess, 879.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 offscreen, 1 onscreen, 870.3ms
# Speed: 1.6ms preprocess, 870.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 883.7ms
# Speed: 2.9ms preprocess, 883.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 offscreen, 2 onscreens, 889.5ms
# Speed: 2.5ms preprocess, 889.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 908.4ms
# Speed: 2.0ms preprocess, 908.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 offscreen, 1 onscreen, 886.7ms
# Speed: 2.9ms preprocess, 886.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 904.5ms
# Speed: 2.0ms preprocess, 904.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 offscreen, 1 onscreen, 880.4ms
# Speed: 2.0ms preprocess, 880.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 874.9ms
# Speed: 2.5ms preprocess, 874.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 offscreen, 1 onscreen, 859.6ms
# Speed: 2.0ms preprocess, 859.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 877.8ms
# Speed: 2.0ms preprocess, 877.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 offscreen, 2 onscreens, 866.8ms
# Speed: 2.9ms preprocess, 866.8ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 869.6ms
# Speed: 2.0ms preprocess, 869.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 offscreen, 1 onscreen, 878.2ms
# Speed: 2.0ms preprocess, 878.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 876.7ms
# Speed: 2.0ms preprocess, 876.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 offscreens, 1 onscreen, 917.2ms
# Speed: 1.5ms preprocess, 917.2ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 866.5ms
# Speed: 2.5ms preprocess, 866.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 offscreen, 1 onscreen, 881.5ms
# Speed: 1.9ms preprocess, 881.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 892.1ms
# Speed: 1.9ms preprocess, 892.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 offscreen, 1 onscreen, 876.3ms
# Speed: 2.0ms preprocess, 876.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 884.2ms
# Speed: 1.9ms preprocess, 884.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 offscreen, 1 onscreen, 878.2ms
# Speed: 1.9ms preprocess, 878.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 870.2ms
# Speed: 2.0ms preprocess, 870.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 offscreen, 2 onscreens, 873.8ms
# Speed: 2.0ms preprocess, 873.8ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 858.1ms
# Speed: 1.0ms preprocess, 858.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 897.7ms
# Speed: 2.0ms preprocess, 897.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 863.8ms
# Speed: 2.5ms preprocess, 863.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 861.2ms
# Speed: 2.5ms preprocess, 861.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 859.2ms
# Speed: 2.0ms preprocess, 859.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 889.8ms
# Speed: 3.0ms preprocess, 889.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 873.3ms
# Speed: 2.5ms preprocess, 873.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 897.2ms
# Speed: 2.5ms preprocess, 897.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 894.6ms
# Speed: 2.5ms preprocess, 894.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 916.3ms
# Speed: 1.9ms preprocess, 916.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 906.9ms
# Speed: 2.0ms preprocess, 906.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 888.3ms
# Speed: 2.9ms preprocess, 888.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 887.7ms
# Speed: 1.9ms preprocess, 887.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 892.8ms
# Speed: 1.9ms preprocess, 892.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 919.0ms
# Speed: 2.0ms preprocess, 919.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 897.0ms
# Speed: 3.0ms preprocess, 897.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 892.1ms
# Speed: 2.0ms preprocess, 892.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 871.6ms
# Speed: 2.0ms preprocess, 871.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 867.3ms
# Speed: 1.6ms preprocess, 867.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 881.4ms
# Speed: 3.0ms preprocess, 881.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 912.7ms
# Speed: 1.9ms preprocess, 912.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 917.8ms
# Speed: 2.0ms preprocess, 917.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 906.5ms
# Speed: 2.0ms preprocess, 906.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 895.6ms
# Speed: 3.5ms preprocess, 895.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 902.2ms
# Speed: 2.0ms preprocess, 902.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 887.7ms
# Speed: 2.0ms preprocess, 887.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 901.4ms
# Speed: 2.0ms preprocess, 901.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 884.9ms
# Speed: 2.0ms preprocess, 884.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 876.9ms
# Speed: 2.0ms preprocess, 876.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 890.2ms
# Speed: 3.0ms preprocess, 890.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 909.7ms
# Speed: 2.0ms preprocess, 909.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 897.5ms
# Speed: 2.0ms preprocess, 897.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 919.8ms
# Speed: 2.7ms preprocess, 919.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 987.2ms
# Speed: 2.0ms preprocess, 987.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 956.5ms
# Speed: 2.0ms preprocess, 956.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 931.3ms
# Speed: 2.0ms preprocess, 931.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 971.5ms
# Speed: 2.5ms preprocess, 971.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 957.9ms
# Speed: 2.0ms preprocess, 957.9ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 12311.2ms
# Speed: 1.5ms preprocess, 12311.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 1756.5ms
# Speed: 2.0ms preprocess, 1756.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1296.6ms
# Speed: 3.0ms preprocess, 1296.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 1031.6ms
# Speed: 1.6ms preprocess, 1031.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1809.1ms
# Speed: 2.0ms preprocess, 1809.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 1021.2ms
# Speed: 2.0ms preprocess, 1021.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1362.8ms
# Speed: 2.0ms preprocess, 1362.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1446.9ms
# Speed: 3.0ms preprocess, 1446.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2046.1ms
# Speed: 2.0ms preprocess, 2046.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1904.7ms
# Speed: 2.9ms preprocess, 1904.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1207.1ms
# Speed: 2.0ms preprocess, 1207.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 1999.3ms
# Speed: 2.7ms preprocess, 1999.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1008.5ms
# Speed: 2.0ms preprocess, 1008.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 945.5ms
# Speed: 2.1ms preprocess, 945.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 987.2ms
# Speed: 3.0ms preprocess, 987.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 928.0ms
# Speed: 2.6ms preprocess, 928.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1031.8ms
# Speed: 2.7ms preprocess, 1031.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 948.4ms
# Speed: 1.5ms preprocess, 948.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 961.2ms
# Speed: 2.6ms preprocess, 961.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 955.8ms
# Speed: 2.0ms preprocess, 955.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 964.6ms
# Speed: 2.1ms preprocess, 964.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 967.8ms
# Speed: 2.5ms preprocess, 967.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 961.0ms
# Speed: 2.1ms preprocess, 961.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 952.1ms
# Speed: 2.0ms preprocess, 952.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 947.1ms
# Speed: 3.0ms preprocess, 947.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 977.6ms
# Speed: 3.0ms preprocess, 977.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 972.0ms
# Speed: 3.0ms preprocess, 972.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1015.1ms
# Speed: 3.5ms preprocess, 1015.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 943.1ms
# Speed: 2.0ms preprocess, 943.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1149.4ms
# Speed: 3.0ms preprocess, 1149.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1761.2ms
# Speed: 3.0ms preprocess, 1761.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1143.6ms
# Speed: 2.0ms preprocess, 1143.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1152.1ms
# Speed: 2.0ms preprocess, 1152.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 978.7ms
# Speed: 3.0ms preprocess, 978.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 989.1ms
# Speed: 2.0ms preprocess, 989.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 1021.3ms
# Speed: 2.0ms preprocess, 1021.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1042.6ms
# Speed: 2.0ms preprocess, 1042.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1253.1ms
# Speed: 3.0ms preprocess, 1253.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 972.7ms
# Speed: 2.1ms preprocess, 972.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 900.1ms
# Speed: 3.0ms preprocess, 900.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 935.9ms
# Speed: 2.0ms preprocess, 935.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 928.7ms
# Speed: 2.8ms preprocess, 928.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 943.4ms
# Speed: 3.1ms preprocess, 943.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 914.1ms
# Speed: 2.0ms preprocess, 914.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 910.3ms
# Speed: 2.6ms preprocess, 910.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 890.6ms
# Speed: 1.9ms preprocess, 890.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 898.0ms
# Speed: 1.9ms preprocess, 898.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 907.0ms
# Speed: 2.8ms preprocess, 907.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 946.5ms
# Speed: 1.7ms preprocess, 946.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 922.1ms
# Speed: 3.0ms preprocess, 922.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 940.9ms
# Speed: 2.5ms preprocess, 940.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 892.0ms
# Speed: 2.0ms preprocess, 892.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 903.1ms
# Speed: 2.0ms preprocess, 903.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 902.1ms
# Speed: 2.0ms preprocess, 902.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 897.4ms
# Speed: 2.0ms preprocess, 897.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 918.1ms
# Speed: 3.1ms preprocess, 918.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 909.4ms
# Speed: 2.0ms preprocess, 909.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 918.3ms
# Speed: 3.6ms preprocess, 918.3ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 879.0ms
# Speed: 2.0ms preprocess, 879.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 906.0ms
# Speed: 2.0ms preprocess, 906.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 907.3ms
# Speed: 2.0ms preprocess, 907.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 934.2ms
# Speed: 2.0ms preprocess, 934.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 898.6ms
# Speed: 2.0ms preprocess, 898.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 889.3ms
# Speed: 2.0ms preprocess, 889.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 899.6ms
# Speed: 2.0ms preprocess, 899.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 894.5ms
# Speed: 3.0ms preprocess, 894.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 893.4ms
# Speed: 2.0ms preprocess, 893.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 893.5ms
# Speed: 2.1ms preprocess, 893.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 908.7ms
# Speed: 2.0ms preprocess, 908.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 889.0ms
# Speed: 2.0ms preprocess, 889.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1001.5ms
# Speed: 2.1ms preprocess, 1001.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 959.0ms
# Speed: 2.0ms preprocess, 959.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1029.3ms
# Speed: 2.0ms preprocess, 1029.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 1049.6ms
# Speed: 2.0ms preprocess, 1049.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 992.9ms
# Speed: 2.0ms preprocess, 992.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 926.2ms
# Speed: 2.0ms preprocess, 926.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 910.1ms
# Speed: 2.1ms preprocess, 910.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 902.3ms
# Speed: 2.9ms preprocess, 902.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 892.5ms
# Speed: 2.7ms preprocess, 892.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 907.4ms
# Speed: 3.0ms preprocess, 907.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 887.9ms
# Speed: 2.0ms preprocess, 887.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 890.5ms
# Speed: 2.0ms preprocess, 890.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 889.3ms
# Speed: 1.9ms preprocess, 889.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 897.4ms
# Speed: 1.6ms preprocess, 897.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 894.9ms
# Speed: 1.0ms preprocess, 894.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 917.2ms
# Speed: 2.6ms preprocess, 917.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 974.3ms
# Speed: 1.7ms preprocess, 974.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 948.0ms
# Speed: 1.9ms preprocess, 948.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 933.9ms
# Speed: 2.5ms preprocess, 933.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 939.7ms
# Speed: 2.6ms preprocess, 939.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 912.8ms
# Speed: 2.0ms preprocess, 912.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 929.0ms
# Speed: 2.0ms preprocess, 929.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 969.0ms
# Speed: 2.0ms preprocess, 969.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 963.2ms
# Speed: 2.0ms preprocess, 963.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1040.5ms
# Speed: 2.0ms preprocess, 1040.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 962.7ms
# Speed: 2.0ms preprocess, 962.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 944.7ms
# Speed: 3.0ms preprocess, 944.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 936.3ms
# Speed: 1.5ms preprocess, 936.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 948.7ms
# Speed: 2.6ms preprocess, 948.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 995.9ms
# Speed: 2.0ms preprocess, 995.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 964.1ms
# Speed: 2.0ms preprocess, 964.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 978.8ms
# Speed: 2.0ms preprocess, 978.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 960.6ms
# Speed: 2.0ms preprocess, 960.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1009.4ms
# Speed: 2.0ms preprocess, 1009.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1095.7ms
# Speed: 3.0ms preprocess, 1095.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1042.0ms
# Speed: 2.0ms preprocess, 1042.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1052.5ms
# Speed: 3.0ms preprocess, 1052.5ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 986.4ms
# Speed: 2.0ms preprocess, 986.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1026.8ms
# Speed: 3.0ms preprocess, 1026.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 995.6ms
# Speed: 2.5ms preprocess, 995.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 968.3ms
# Speed: 2.0ms preprocess, 968.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 951.5ms
# Speed: 2.1ms preprocess, 951.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 936.3ms
# Speed: 2.0ms preprocess, 936.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 949.8ms
# Speed: 2.0ms preprocess, 949.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 985.8ms
# Speed: 1.5ms preprocess, 985.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 932.2ms
# Speed: 3.0ms preprocess, 932.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 946.5ms
# Speed: 2.0ms preprocess, 946.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 997.3ms
# Speed: 1.9ms preprocess, 997.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 940.2ms
# Speed: 2.6ms preprocess, 940.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1012.7ms
# Speed: 2.0ms preprocess, 1012.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 977.1ms
# Speed: 2.0ms preprocess, 977.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 962.8ms
# Speed: 2.0ms preprocess, 962.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1077.6ms
# Speed: 2.6ms preprocess, 1077.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 974.6ms
# Speed: 2.0ms preprocess, 974.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1039.5ms
# Speed: 2.0ms preprocess, 1039.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 937.1ms
# Speed: 2.5ms preprocess, 937.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 993.3ms
# Speed: 1.9ms preprocess, 993.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1006.7ms
# Speed: 2.6ms preprocess, 1006.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 966.5ms
# Speed: 2.6ms preprocess, 966.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1037.9ms
# Speed: 3.0ms preprocess, 1037.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 952.1ms
# Speed: 2.0ms preprocess, 952.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 965.4ms
# Speed: 3.0ms preprocess, 965.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 992.7ms
# Speed: 2.1ms preprocess, 992.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 967.1ms
# Speed: 2.5ms preprocess, 967.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1017.4ms
# Speed: 2.0ms preprocess, 1017.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 978.3ms
# Speed: 3.0ms preprocess, 978.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 964.0ms
# Speed: 3.0ms preprocess, 964.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 941.7ms
# Speed: 2.0ms preprocess, 941.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 946.6ms
# Speed: 2.7ms preprocess, 946.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1054.2ms
# Speed: 3.0ms preprocess, 1054.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 970.5ms
# Speed: 2.0ms preprocess, 970.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1007.2ms
# Speed: 3.0ms preprocess, 1007.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 970.1ms
# Speed: 2.0ms preprocess, 970.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 949.0ms
# Speed: 2.0ms preprocess, 949.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 983.8ms
# Speed: 2.0ms preprocess, 983.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 945.7ms
# Speed: 2.0ms preprocess, 945.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1049.6ms
# Speed: 2.1ms preprocess, 1049.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 971.3ms
# Speed: 2.0ms preprocess, 971.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 936.9ms
# Speed: 2.4ms preprocess, 936.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 946.1ms
# Speed: 3.0ms preprocess, 946.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1039.1ms
# Speed: 2.0ms preprocess, 1039.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 968.9ms
# Speed: 3.1ms preprocess, 968.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 950.0ms
# Speed: 2.7ms preprocess, 950.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 984.7ms
# Speed: 2.0ms preprocess, 984.7ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 997.6ms
# Speed: 2.0ms preprocess, 997.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 997.6ms
# Speed: 2.5ms preprocess, 997.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 993.7ms
# Speed: 2.5ms preprocess, 993.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 955.9ms
# Speed: 1.9ms preprocess, 955.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 952.0ms
# Speed: 2.6ms preprocess, 952.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 934.8ms
# Speed: 2.0ms preprocess, 934.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 952.1ms
# Speed: 2.0ms preprocess, 952.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 941.5ms
# Speed: 2.0ms preprocess, 941.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 946.7ms
# Speed: 3.0ms preprocess, 946.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 920.1ms
# Speed: 2.6ms preprocess, 920.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 903.9ms
# Speed: 2.0ms preprocess, 903.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 904.8ms
# Speed: 1.0ms preprocess, 904.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 915.7ms
# Speed: 3.1ms preprocess, 915.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 919.7ms
# Speed: 2.0ms preprocess, 919.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 894.2ms
# Speed: 2.0ms preprocess, 894.2ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 889.6ms
# Speed: 2.0ms preprocess, 889.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 899.6ms
# Speed: 2.1ms preprocess, 899.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 932.0ms
# Speed: 2.0ms preprocess, 932.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 939.1ms
# Speed: 3.0ms preprocess, 939.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 926.0ms
# Speed: 3.0ms preprocess, 926.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 925.8ms
# Speed: 2.1ms preprocess, 925.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 916.2ms
# Speed: 2.4ms preprocess, 916.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 897.8ms
# Speed: 1.6ms preprocess, 897.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 888.9ms
# Speed: 3.0ms preprocess, 888.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 909.0ms
# Speed: 2.0ms preprocess, 909.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 888.2ms
# Speed: 2.5ms preprocess, 888.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 884.9ms
# Speed: 2.5ms preprocess, 884.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 885.6ms
# Speed: 3.0ms preprocess, 885.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 907.7ms
# Speed: 2.0ms preprocess, 907.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 887.1ms
# Speed: 2.0ms preprocess, 887.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 870.9ms
# Speed: 1.5ms preprocess, 870.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 897.2ms
# Speed: 2.0ms preprocess, 897.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 866.4ms
# Speed: 2.0ms preprocess, 866.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 896.8ms
# Speed: 2.0ms preprocess, 896.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 892.5ms
# Speed: 2.0ms preprocess, 892.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 884.8ms
# Speed: 1.9ms preprocess, 884.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 916.6ms
# Speed: 2.0ms preprocess, 916.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 901.2ms
# Speed: 3.0ms preprocess, 901.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 908.4ms
# Speed: 2.5ms preprocess, 908.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 885.2ms
# Speed: 2.0ms preprocess, 885.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 886.0ms
# Speed: 2.6ms preprocess, 886.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 879.9ms
# Speed: 2.9ms preprocess, 879.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 895.3ms
# Speed: 2.0ms preprocess, 895.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 854.0ms
# Speed: 2.0ms preprocess, 854.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 896.9ms
# Speed: 1.7ms preprocess, 896.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 876.3ms
# Speed: 3.0ms preprocess, 876.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 892.7ms
# Speed: 2.0ms preprocess, 892.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 890.5ms
# Speed: 2.0ms preprocess, 890.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 887.0ms
# Speed: 2.0ms preprocess, 887.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 880.6ms
# Speed: 2.0ms preprocess, 880.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 886.9ms
# Speed: 3.0ms preprocess, 886.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 894.3ms
# Speed: 3.1ms preprocess, 894.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 892.0ms
# Speed: 2.0ms preprocess, 892.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 894.6ms
# Speed: 2.0ms preprocess, 894.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 891.6ms
# Speed: 2.0ms preprocess, 891.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 891.2ms
# Speed: 2.5ms preprocess, 891.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 885.8ms
# Speed: 2.0ms preprocess, 885.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 898.1ms
# Speed: 2.0ms preprocess, 898.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 882.8ms
# Speed: 2.0ms preprocess, 882.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 878.9ms
# Speed: 2.0ms preprocess, 878.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 881.9ms
# Speed: 1.9ms preprocess, 881.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 896.9ms
# Speed: 2.0ms preprocess, 896.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 912.6ms
# Speed: 2.0ms preprocess, 912.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 891.6ms
# Speed: 2.1ms preprocess, 891.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 892.7ms
# Speed: 2.0ms preprocess, 892.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 881.2ms
# Speed: 3.1ms preprocess, 881.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 901.5ms
# Speed: 2.0ms preprocess, 901.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 914.2ms
# Speed: 2.0ms preprocess, 914.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 914.5ms
# Speed: 1.5ms preprocess, 914.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 892.8ms
# Speed: 1.9ms preprocess, 892.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 880.6ms
# Speed: 2.0ms preprocess, 880.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 885.5ms
# Speed: 2.0ms preprocess, 885.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 893.0ms
# Speed: 2.0ms preprocess, 893.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 889.8ms
# Speed: 3.0ms preprocess, 889.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 882.2ms
# Speed: 1.8ms preprocess, 882.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 865.4ms
# Speed: 1.9ms preprocess, 865.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 881.0ms
# Speed: 2.0ms preprocess, 881.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 881.4ms
# Speed: 1.9ms preprocess, 881.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 890.9ms
# Speed: 2.0ms preprocess, 890.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 907.1ms
# Speed: 1.7ms preprocess, 907.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 897.0ms
# Speed: 2.5ms preprocess, 897.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 912.2ms
# Speed: 3.0ms preprocess, 912.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 889.1ms
# Speed: 2.0ms preprocess, 889.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 889.2ms
# Speed: 3.0ms preprocess, 889.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 894.6ms
# Speed: 2.0ms preprocess, 894.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 873.5ms
# Speed: 2.0ms preprocess, 873.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 875.0ms
# Speed: 2.0ms preprocess, 875.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 901.2ms
# Speed: 1.5ms preprocess, 901.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 879.4ms
# Speed: 2.0ms preprocess, 879.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 854.1ms
# Speed: 1.6ms preprocess, 854.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 885.7ms
# Speed: 2.0ms preprocess, 885.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 904.9ms
# Speed: 2.0ms preprocess, 904.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 875.8ms
# Speed: 2.0ms preprocess, 875.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 878.0ms
# Speed: 2.0ms preprocess, 878.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 880.9ms
# Speed: 2.1ms preprocess, 880.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 879.3ms
# Speed: 3.0ms preprocess, 879.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 899.0ms
# Speed: 2.0ms preprocess, 899.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 902.6ms
# Speed: 2.0ms preprocess, 902.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 872.6ms
# Speed: 1.5ms preprocess, 872.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 877.4ms
# Speed: 2.5ms preprocess, 877.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 882.4ms
# Speed: 2.7ms preprocess, 882.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 876.9ms
# Speed: 1.0ms preprocess, 876.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 923.2ms
# ...
#
# 0: 384x640 1 offscreen, 875.6ms
# Speed: 2.0ms preprocess, 875.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 870.5ms
# Speed: 1.9ms preprocess, 870.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 883.2ms
# Speed: 2.5ms preprocess, 883.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 878.2ms
# Speed: 2.0ms preprocess, 878.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 876.8ms
# Speed: 1.9ms preprocess, 876.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 904.3ms
# Speed: 2.0ms preprocess, 904.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 920.4ms
# Speed: 2.0ms preprocess, 920.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 924.5ms
# Speed: 2.0ms preprocess, 924.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 895.8ms
# Speed: 2.0ms preprocess, 895.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 889.2ms
# Speed: 2.0ms preprocess, 889.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 880.3ms
# Speed: 2.0ms preprocess, 880.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 901.7ms
# Speed: 2.0ms preprocess, 901.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 890.9ms
# Speed: 2.5ms preprocess, 890.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 880.4ms
# Speed: 2.5ms preprocess, 880.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 890.5ms
# Speed: 1.5ms preprocess, 890.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 884.1ms
# Speed: 2.0ms preprocess, 884.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 875.8ms
# Speed: 2.0ms preprocess, 875.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 890.3ms
# Speed: 2.0ms preprocess, 890.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 885.8ms
# Speed: 2.5ms preprocess, 885.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 870.3ms
# Speed: 2.0ms preprocess, 870.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 883.7ms
# Speed: 2.0ms preprocess, 883.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 865.5ms
# Speed: 2.0ms preprocess, 865.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 874.4ms
# Speed: 1.5ms preprocess, 874.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 871.4ms
# Speed: 1.0ms preprocess, 871.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 881.7ms
# Speed: 2.0ms preprocess, 881.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 877.2ms
# Speed: 2.0ms preprocess, 877.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 889.8ms
# Speed: 2.0ms preprocess, 889.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 884.6ms
# Speed: 2.0ms preprocess, 884.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 878.3ms
# Speed: 2.0ms preprocess, 878.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 910.7ms
# Speed: 2.0ms preprocess, 910.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 890.8ms
# Speed: 2.6ms preprocess, 890.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 880.9ms
# Speed: 2.6ms preprocess, 880.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 881.8ms
# Speed: 2.0ms preprocess, 881.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 867.4ms
# Speed: 2.6ms preprocess, 867.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 875.1ms
# Speed: 2.0ms preprocess, 875.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 884.3ms
# Speed: 1.0ms preprocess, 884.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 864.8ms
# Speed: 2.5ms preprocess, 864.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 864.3ms
# Speed: 2.0ms preprocess, 864.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 879.3ms
# Speed: 2.0ms preprocess, 879.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 869.0ms
# Speed: 2.0ms preprocess, 869.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 883.6ms
# Speed: 1.9ms preprocess, 883.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 887.0ms
# Speed: 2.0ms preprocess, 887.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 858.4ms
# Speed: 2.0ms preprocess, 858.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 950.7ms
# Speed: 2.0ms preprocess, 950.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 902.2ms
# Speed: 2.5ms preprocess, 902.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 905.4ms
# Speed: 2.0ms preprocess, 905.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 869.7ms
# Speed: 2.0ms preprocess, 869.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 896.4ms
# Speed: 2.0ms preprocess, 896.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 879.3ms
# Speed: 2.6ms preprocess, 879.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 887.0ms
# Speed: 1.5ms preprocess, 887.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 929.7ms
# Speed: 2.0ms preprocess, 929.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 871.9ms
# Speed: 2.0ms preprocess, 871.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 876.3ms
# Speed: 2.0ms preprocess, 876.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 867.3ms
# Speed: 1.6ms preprocess, 867.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 874.6ms
# Speed: 1.9ms preprocess, 874.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 872.9ms
# Speed: 2.1ms preprocess, 872.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 877.2ms
# Speed: 2.0ms preprocess, 877.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 865.5ms
# Speed: 1.0ms preprocess, 865.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 877.4ms
# Speed: 2.5ms preprocess, 877.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 875.8ms
# Speed: 2.6ms preprocess, 875.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 862.2ms
# Speed: 2.0ms preprocess, 862.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 885.7ms
# Speed: 2.0ms preprocess, 885.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 899.4ms
# Speed: 2.0ms preprocess, 899.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 903.6ms
# Speed: 2.0ms preprocess, 903.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 885.9ms
# Speed: 3.0ms preprocess, 885.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 929.5ms
# Speed: 2.0ms preprocess, 929.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 882.5ms
# Speed: 3.0ms preprocess, 882.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 879.6ms
# Speed: 2.0ms preprocess, 879.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 881.0ms
# Speed: 2.0ms preprocess, 881.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 875.2ms
# Speed: 2.0ms preprocess, 875.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 881.0ms
# Speed: 2.0ms preprocess, 881.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 886.0ms
# Speed: 2.0ms preprocess, 886.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 876.6ms
# Speed: 2.0ms preprocess, 876.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 871.8ms
# Speed: 2.0ms preprocess, 871.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 918.1ms
# Speed: 2.0ms preprocess, 918.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 901.0ms
# Speed: 2.5ms preprocess, 901.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 903.1ms
# Speed: 1.9ms preprocess, 903.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 902.1ms
# Speed: 2.1ms preprocess, 902.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 911.0ms
# Speed: 2.0ms preprocess, 911.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 889.6ms
# Speed: 2.0ms preprocess, 889.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 879.0ms
# Speed: 2.0ms preprocess, 879.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 872.2ms
# Speed: 2.0ms preprocess, 872.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 877.7ms
# Speed: 2.0ms preprocess, 877.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 879.3ms
# Speed: 2.0ms preprocess, 879.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 870.1ms
# Speed: 2.0ms preprocess, 870.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 872.0ms
# Speed: 2.0ms preprocess, 872.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 891.0ms
# Speed: 2.6ms preprocess, 891.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 877.0ms
# Speed: 2.0ms preprocess, 877.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 875.6ms
# Speed: 3.5ms preprocess, 875.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 878.6ms
# Speed: 2.0ms preprocess, 878.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 869.7ms
# Speed: 1.0ms preprocess, 869.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 866.8ms
# Speed: 2.0ms preprocess, 866.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 899.1ms
# Speed: 1.5ms preprocess, 899.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 879.6ms
# Speed: 2.0ms preprocess, 879.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 868.9ms
# Speed: 3.0ms preprocess, 868.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 888.7ms
# Speed: 2.0ms preprocess, 888.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 869.1ms
# Speed: 2.0ms preprocess, 869.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 898.1ms
# Speed: 2.0ms preprocess, 898.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 903.7ms
# Speed: 1.9ms preprocess, 903.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 923.0ms
# Speed: 2.0ms preprocess, 923.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 958.5ms
# Speed: 3.0ms preprocess, 958.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 991.2ms
# Speed: 2.0ms preprocess, 991.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 878.8ms
# Speed: 2.0ms preprocess, 878.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 879.9ms
# Speed: 3.0ms preprocess, 879.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 862.8ms
# Speed: 1.9ms preprocess, 862.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 868.7ms
# Speed: 2.0ms preprocess, 868.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 879.8ms
# Speed: 3.0ms preprocess, 879.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 891.9ms
# Speed: 2.0ms preprocess, 891.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 889.8ms
# Speed: 2.1ms preprocess, 889.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 870.9ms
# Speed: 2.0ms preprocess, 870.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 868.0ms
# Speed: 2.0ms preprocess, 868.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 879.1ms
# Speed: 2.0ms preprocess, 879.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 899.5ms
# Speed: 2.0ms preprocess, 899.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 933.0ms
# Speed: 2.0ms preprocess, 933.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 922.4ms
# Speed: 2.0ms preprocess, 922.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 963.8ms
# Speed: 2.0ms preprocess, 963.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 929.4ms
# Speed: 3.0ms preprocess, 929.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 932.1ms
# Speed: 2.1ms preprocess, 932.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 944.6ms
# Speed: 2.0ms preprocess, 944.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 902.5ms
# Speed: 3.0ms preprocess, 902.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 900.8ms
# Speed: 3.0ms preprocess, 900.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 881.1ms
# Speed: 2.0ms preprocess, 881.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 onscreens, 926.7ms
# Speed: 3.0ms preprocess, 926.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
# GRADIO INTEGRATION

# %%
import gradio as gr
import cv2
import numpy as np
from ultralytics import YOLO
from scipy.spatial import distance
from io import BytesIO
import tempfile

def process_frame(frame, model_human, model_screen):
    display_size = (800, 600)
    
    # Perform prediction using the models
    r = model_human.predict(frame)
    l = model_screen.predict(frame)
    
    # Check if predictions are not None
    if r[0] is None or l[0] is None:
        return cv2.resize(frame, display_size, interpolation=cv2.INTER_AREA)
    
    # Draw polygons for model_screen
    screen_polygons = []
    if l[0].masks is not None:
        for mask_points in l[0].masks.xy:
            polygon_points = np.array(mask_points, np.int32)
            polygon_points = polygon_points.reshape((-1, 1, 2))
            screen_polygons.append(polygon_points)
    
    # Draw polygons for model_human
    human_polygons = []
    if r[0].masks is not None:
        for mask_points in r[0].masks.xy:
            polygon_points = np.array(mask_points, np.int32)
            polygon_points = polygon_points.reshape((-1, 1, 2))
            human_polygons.append(polygon_points)
    
    # Process human polygons and screen polygons
    for human_polygon in human_polygons:
        min_dist = float('inf')
        closest_human_point = None
        closest_screen_point = None
        closest_screen_polygon = None
        
        # Find the nearest screen polygon
        for screen_polygon in screen_polygons:
            for human_point in human_polygon:
                for screen_point in screen_polygon:
                    dist = distance.euclidean(human_point[0], screen_point[0])
                    if dist < min_dist:
                        min_dist = dist
                        closest_human_point = human_point[0]
                        closest_screen_point = screen_point[0]
                        closest_screen_polygon = screen_polygon
        
        # Draw the line and masks if a valid closest point is found
        if closest_human_point is not None and closest_screen_point is not None:
            cv2.line(frame, tuple(closest_human_point), tuple(closest_screen_point), color=(255, 0, 0), thickness=5)
            
            # Display the Euclidean distance
            midpoint = ((closest_human_point[0] + closest_screen_point[0]) // 2,
                        (closest_human_point[1] + closest_screen_point[1]) // 2)
            cv2.putText(frame, f"{min_dist:.2f}", midpoint, cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 2)
            
            # Check if the distance is greater than 444
            if min_dist > 444 and closest_screen_polygon is not None:
                # Draw a violet polygon around the screen
                cv2.polylines(frame, [closest_screen_polygon], isClosed=True, color=(238, 130, 238), thickness=5)

        # Mark screen polygons
        if closest_screen_polygon is not None:
            screen_color = (0, 255, 0) if min_dist < 400 else (238, 130, 238)
            cv2.fillPoly(frame, [closest_screen_polygon], color=screen_color)

    # Resize the image for display
    resized_frame = cv2.resize(frame, display_size, interpolation=cv2.INTER_AREA)
    
    return resized_frame

def video_to_frames(video_file_path):
    # Read the video file
    cap = cv2.VideoCapture(video_file_path)
    
    # Load the models
    model_human = YOLO("best (HUM).pt")
    model_screen = YOLO("best_SCR.pt")
    
    # Prepare the video writer
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    
    # Create a temporary file to save the video output
    temp_output = tempfile.NamedTemporaryFile(delete=False, suffix=".mp4")
    out = cv2.VideoWriter(temp_output.name, fourcc, fps, (width, height))
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        # Process the frame
        processed_frame = process_frame(frame, model_human, model_screen)
        
        # Write the processed frame to the output video
        out.write(processed_frame)
    
    cap.release()
    out.release()
    
    return temp_output.name

def process_video(video_file):
    output_file_path = video_to_frames(video_file)
    return output_file_path

iface = gr.Interface(
    fn=process_video,
    inputs=gr.Video(),
    outputs=gr.Video(),
    title="YOLO Video Processing",
    description="Upload a video and get processed results with YOLO models drawing polygons and calculating distances."
)

iface.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7865
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7865/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 0: 384x640 1 person, 1702.1ms
# Speed: 7.0ms preprocess, 1702.1ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1656.4ms
# Speed: 3.1ms preprocess, 1656.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1649.2ms
# Speed: 3.0ms preprocess, 1649.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1702.8ms
# Speed: 26.0ms preprocess, 1702.8ms inference, 19.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1636.2ms
# Speed: 2.9ms preprocess, 1636.2ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1686.1ms
# Speed: 15.0ms preprocess, 1686.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1663.6ms
# Speed: 2.0ms preprocess, 1663.6ms inference, 16.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1639.4ms
# Speed: 4.0ms preprocess, 1639.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1673.4ms
# Speed: 3.0ms preprocess, 1673.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1738.2ms
# Speed: 3.0ms preprocess, 1738.2ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1664.4ms
# Speed: 3.0ms preprocess, 1664.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1522.3ms
# Speed: 5.0ms preprocess, 1522.3ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1656.0ms
# Speed: 8.9ms preprocess, 1656.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1652.2ms
# Speed: 3.0ms preprocess, 1652.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1615.8ms
# Speed: 2.9ms preprocess, 1615.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1668.8ms
# Speed: 7.0ms preprocess, 1668.8ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1613.9ms
# Speed: 4.1ms preprocess, 1613.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1648.9ms
# Speed: 3.0ms preprocess, 1648.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1678.6ms
# Speed: 2.9ms preprocess, 1678.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1677.9ms
# Speed: 2.0ms preprocess, 1677.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1655.0ms
# Speed: 3.0ms preprocess, 1655.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 2025.6ms
# Speed: 9.0ms preprocess, 2025.6ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1900.1ms
# Speed: 3.0ms preprocess, 1900.1ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1794.6ms
# Speed: 4.0ms preprocess, 1794.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1693.1ms
# Speed: 3.0ms preprocess, 1693.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1701.1ms
# Speed: 6.0ms preprocess, 1701.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1678.7ms
# Speed: 3.0ms preprocess, 1678.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1683.9ms
# Speed: 7.0ms preprocess, 1683.9ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1536.8ms
# Speed: 36.9ms preprocess, 1536.8ms inference, 19.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1633.6ms
# Speed: 4.9ms preprocess, 1633.6ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1701.5ms
# Speed: 28.0ms preprocess, 1701.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1690.6ms
# Speed: 4.0ms preprocess, 1690.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1619.1ms
# Speed: 8.0ms preprocess, 1619.1ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1636.2ms
# Speed: 4.0ms preprocess, 1636.2ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1641.1ms
# Speed: 5.0ms preprocess, 1641.1ms inference, 21.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1663.3ms
# Speed: 6.0ms preprocess, 1663.3ms inference, 23.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1620.5ms
# Speed: 3.0ms preprocess, 1620.5ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1672.0ms
# Speed: 1.9ms preprocess, 1672.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1660.0ms
# Speed: 4.0ms preprocess, 1660.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1689.0ms
# Speed: 3.0ms preprocess, 1689.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1599.0ms
# Speed: 3.0ms preprocess, 1599.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1685.3ms
# Speed: 6.0ms preprocess, 1685.3ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1665.3ms
# Speed: 3.0ms preprocess, 1665.3ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1655.5ms
# Speed: 3.0ms preprocess, 1655.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1534.5ms
# Speed: 104.7ms preprocess, 1534.5ms inference, 33.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1631.0ms
# Speed: 13.0ms preprocess, 1631.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1520.0ms
# Speed: 7.1ms preprocess, 1520.0ms inference, 17.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1672.9ms
# Speed: 12.0ms preprocess, 1672.9ms inference, 13.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1657.9ms
# Speed: 5.0ms preprocess, 1657.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1586.4ms
# Speed: 4.0ms preprocess, 1586.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1645.3ms
# Speed: 4.0ms preprocess, 1645.3ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1669.7ms
# Speed: 3.0ms preprocess, 1669.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1713.0ms
# Speed: 3.0ms preprocess, 1713.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 onscreen, 1628.4ms
# Speed: 4.0ms preprocess, 1628.4ms inference, 11.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1679.7ms
# Speed: 3.0ms preprocess, 1679.7ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
